# %%
import pyspark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import regexp_replace, col, udf, avg, when
from pyspark.sql.window import Window
from pyspark.sql.types import FloatType
from datetime import datetime

# %%
# Start Spark Session
spark = SparkSession.builder.appName("CarAnalytics").getOrCreate()

# Load the dataset
file_path = "dataset_cleaned.csv"  # Update with the correct path
df = spark.read.csv(file_path, header=True, inferSchema=True)

# -----------------------
# 1. Data Preparation
# -----------------------

# drop column
df = df.drop("Name").drop("Engine").drop("Transmission").drop("condition").drop("Type")

df = df.withColumn("Mileage", regexp_replace(col("Mileage"), "[^0-9]", "").cast(FloatType()))

# Convert 'Giá' (Price) to numeric (e.g., "520 triệu" -> 520.000.000)
def clean_price(price):
    if price:
        price = price.replace(" tỉ ", "").replace(",", "").strip()
        price = price.replace(" triệu", "").replace(",", "").strip()
        return float(price) * 1e6 if price.isnumeric() else None
    return None

clean_price_udf = udf(clean_price, FloatType())
df = df.withColumn("Price", clean_price_udf(col("Price")))

# Add a new column for car age
df = df.withColumn("Car Age", datetime.now().year - col("Year"))

# convert null mileage to 0
df = df.withColumn("Mileage", when(col("Mileage").isNull(), 0).otherwise(col("Mileage")))

print(df.show())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-66a16de6feec> in <cell line: 2>()
#       1 # Start Spark Session
# ----> 2 spark = SparkSession.builder.appName("CarAnalytics").getOrCreate()
#       3
#       4 # Load the dataset
#       5 file_path = "dataset_cleaned.csv"  # Update with the correct path
#
# NameError: name 'SparkSession' is not defined

# %%
# -----------------------
# 2. Complex Aggregations
# -----------------------

# Window Function: Average price by brand and year
window_spec = Window.partitionBy("Thương hiệu").orderBy("Năm SX")
df = df.withColumn("Avg Price by Brand", avg("Giá").over(window_spec))

# Pivot Operation: Average price by fuel type and body style
pivot_df = df.groupBy("Nhiên liệu").pivot("Kiểu dáng").avg("Giá")

print(df.show())
# Out:
# +-----------+--------+------+---------+----------+----------+--------+----------+----------+----------+------------+-------+--------------------+
# |Thương hiệu|   Model|Năm SX|Kiểu dáng|Tình trạng|   Xuất xứ|Km đã đi|Tỉnh thành|Quận huyện|Nhiên liệu|         Giá|Car Age|  Avg Price by Brand|
# +-----------+--------+------+---------+----------+----------+--------+----------+----------+----------+------------+-------+--------------------+
# |        BMW|    Khác|  2011|    Sedan|     Xe cũ| Nhập khẩu| 83000.0|    Hà Nội| Hoàng Mai|  Máy xăng|      6.35E8|     13|              6.35E8|
# |        BMW|    Khác|  2016|    Sedan|     Xe cũ| Nhập khẩu| 79000.0|    Hà Nội| Hoàng Mai|  Máy xăng|      5.99E8|      8|              6.17E8|
# |        BMW|    Khác|  2020|    Sedan|     Xe cũ| Nhập khẩu| 44300.0|    Hà Nội| Hoàng Mai|  Máy xăng|3.19000013E9|      4|1.4746667093333333E9|
# |        BMW|      X3|  2021|      SUV|     Xe cũ| Nhập khẩu| 61000.0|    Hà Nội| Hoàng Mai|  Máy xăng|      1.46E9|      3|       1.471000032E9|
# |        BMW|    Khác|  2024|    Sedan|    Xe mới|Trong nước|     0.0|    Tp.HCM| Phú Nhuận|  Máy xăng|     1.466E9|      0|      1.4700000256E9|
# |    Bentley|Mulsanne|  2014|    Sedan|     Xe cũ| Nhập khẩu| 53000.0|    Hà Nội| Hoàng Mai|  Máy xăng| 7.9000003E9|     10|       7.900000256E9|
# |      Chery|    Khác|  2024|     NULL|    Xe mới| Nhập khẩu|     0.0|    Hà Nội|  Cầu Giấy|  Máy xăng|      5.89E8|      0|              5.89E8|
# |       Ford|EcoSport|  2018|Crossover|     Xe cũ|Trong nước| 30000.0|    Tp.HCM|   Tân Phú|  Máy xăng|      4.35E8|      6|              4.35E8|
# |       Ford|  Ranger|  2019|  Bán tải|     Xe cũ|Trong nước| 68000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      5.35E8|      5|              5.45E8|
# |       Ford| Tourneo|  2019|      MPV|     Xe cũ|Trong nước| 72000.0|    Tp.HCM|   Thủ Đức|  Máy xăng|      6.65E8|      5|              5.45E8|
# |       Ford|EcoSport|  2020|      SUV|     Xe cũ|Trong nước| 37000.0|    Tp.HCM|   Tân Phú|  Máy xăng|      4.85E8|      4|               5.3E8|
# |       Ford|  Ranger|  2021|  Bán tải|     Xe cũ| Nhập khẩu| 70000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      7.25E8|      3| 6.254285714285715E8|
# |       Ford|  Ranger|  2021|  Bán tải|     Xe cũ| Nhập khẩu| 40000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      5.95E8|      3| 6.254285714285715E8|
# |       Ford| Everest|  2021|      SUV|     Xe cũ| Nhập khẩu| 55000.0|    Tp.HCM|   Thủ Đức|   Máy dầu|      9.38E8|      3| 6.254285714285715E8|
# |       Ford|  Ranger|  2022|  Bán tải|     Xe cũ|Trong nước| 24000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      1.01E9|      2|       7.377999936E8|
# |       Ford| Everest|  2022|      SUV|     Xe cũ| Nhập khẩu| 60000.0|    Tp.HCM|   Tân Phú|   Máy dầu|1.34499994E9|      2|       7.377999936E8|
# |       Ford|  Ranger|  2022|  Bán tải|     Xe cũ|Trong nước| 70000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      6.45E8|      2|       7.377999936E8|
# |       Ford|  Ranger|  2023|  Bán tải|     Xe cũ|Trong nước| 16000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      6.88E8|      1| 7.309166613333334E8|
# |       Ford|  Ranger|  2023|  Bán tải|     Xe cũ|Trong nước| 22000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      7.05E8|      1| 7.309166613333334E8|
# |       Ford|  Ranger|  2024|  Bán tải|     Xe cũ|Trong nước| 17000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      6.85E8|      0|        7.98687492E8|
# +-----------+--------+------+---------+----------+----------+--------+----------+----------+----------+------------+-------+--------------------+
# only showing top 20 rows
#
# None

# %%
# 3.Transformations

df = df.filter(col("Năm SX") >= 2015)

# Custom UDF: Categorize cars by price range
def categorize_price(price):
    if not price:
        return None
    if price < 500000000:
        return "Low"
    elif price < 1000000000:
        return "Mid"
    return "High"

categorize_price_udf = udf(categorize_price)
df = df.withColumn("Price Category", categorize_price_udf(col("Giá")))
print(df.show())
# Out:
# +-----------+--------+------+---------+----------+----------+--------+----------+----------+----------+------------+-------+--------------------+--------------+
# |Thương hiệu|   Model|Năm SX|Kiểu dáng|Tình trạng|   Xuất xứ|Km đã đi|Tỉnh thành|Quận huyện|Nhiên liệu|         Giá|Car Age|  Avg Price by Brand|Price Category|
# +-----------+--------+------+---------+----------+----------+--------+----------+----------+----------+------------+-------+--------------------+--------------+
# |        BMW|    Khác|  2016|    Sedan|     Xe cũ| Nhập khẩu| 79000.0|    Hà Nội| Hoàng Mai|  Máy xăng|      5.99E8|      8|              6.17E8|           Mid|
# |        BMW|    Khác|  2020|    Sedan|     Xe cũ| Nhập khẩu| 44300.0|    Hà Nội| Hoàng Mai|  Máy xăng|3.19000013E9|      4|1.4746667093333333E9|          High|
# |        BMW|      X3|  2021|      SUV|     Xe cũ| Nhập khẩu| 61000.0|    Hà Nội| Hoàng Mai|  Máy xăng|      1.46E9|      3|       1.471000032E9|          High|
# |        BMW|    Khác|  2024|    Sedan|    Xe mới|Trong nước|     0.0|    Tp.HCM| Phú Nhuận|  Máy xăng|     1.466E9|      0|      1.4700000256E9|          High|
# |      Chery|    Khác|  2024|     NULL|    Xe mới| Nhập khẩu|     0.0|    Hà Nội|  Cầu Giấy|  Máy xăng|      5.89E8|      0|              5.89E8|           Mid|
# |       Ford|EcoSport|  2018|Crossover|     Xe cũ|Trong nước| 30000.0|    Tp.HCM|   Tân Phú|  Máy xăng|      4.35E8|      6|              4.35E8|           Low|
# |       Ford|  Ranger|  2019|  Bán tải|     Xe cũ|Trong nước| 68000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      5.35E8|      5|              5.45E8|           Mid|
# |       Ford| Tourneo|  2019|      MPV|     Xe cũ|Trong nước| 72000.0|    Tp.HCM|   Thủ Đức|  Máy xăng|      6.65E8|      5|              5.45E8|           Mid|
# |       Ford|EcoSport|  2020|      SUV|     Xe cũ|Trong nước| 37000.0|    Tp.HCM|   Tân Phú|  Máy xăng|      4.85E8|      4|               5.3E8|           Low|
# |       Ford|  Ranger|  2021|  Bán tải|     Xe cũ| Nhập khẩu| 70000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      7.25E8|      3| 6.254285714285715E8|           Mid|
# |       Ford|  Ranger|  2021|  Bán tải|     Xe cũ| Nhập khẩu| 40000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      5.95E8|      3| 6.254285714285715E8|           Mid|
# |       Ford| Everest|  2021|      SUV|     Xe cũ| Nhập khẩu| 55000.0|    Tp.HCM|   Thủ Đức|   Máy dầu|      9.38E8|      3| 6.254285714285715E8|           Mid|
# |       Ford|  Ranger|  2022|  Bán tải|     Xe cũ|Trong nước| 24000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      1.01E9|      2|       7.377999936E8|          High|
# |       Ford| Everest|  2022|      SUV|     Xe cũ| Nhập khẩu| 60000.0|    Tp.HCM|   Tân Phú|   Máy dầu|1.34499994E9|      2|       7.377999936E8|          High|
# |       Ford|  Ranger|  2022|  Bán tải|     Xe cũ|Trong nước| 70000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      6.45E8|      2|       7.377999936E8|           Mid|
# |       Ford|  Ranger|  2023|  Bán tải|     Xe cũ|Trong nước| 16000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      6.88E8|      1| 7.309166613333334E8|           Mid|
# |       Ford|  Ranger|  2023|  Bán tải|     Xe cũ|Trong nước| 22000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      7.05E8|      1| 7.309166613333334E8|           Mid|
# |       Ford|  Ranger|  2024|  Bán tải|     Xe cũ|Trong nước| 17000.0|    Tp.HCM|   Tân Phú|   Máy dầu|      6.85E8|      0|        7.98687492E8|           Mid|
# |       Ford| Transit|  2024|  Minibus|    Xe mới|Trong nước|     0.0|    Tp.HCM|   Tân Phú|   Máy dầu|      9.74E8|      0|        7.98687492E8|           Mid|
# |       Ford|  Ranger|  2024|  Bán tải|    Xe mới| Nhập khẩu|     0.0|    Tp.HCM|   Tân Phú|   Máy dầu|     1.216E9|      0|        7.98687492E8|          High|
# +-----------+--------+------+---------+----------+----------+--------+----------+----------+----------+------------+-------+--------------------+--------------+
# only showing top 20 rows
#
# None

# %%
# Stop Spark Session
spark.stop()
